# %%
import requests
import json
import pandas as pd

# %%
# https://harrywang.medium.com/how-to-organize-a-self-contained-python-project-dc5ac3e1ebfa --> Self Contained

# %%
api_key = "4a6cee856dda9f4bb8bd40415da3ebde"
lat = "48.208176"
lon = "16.373819"
url = "https://api.openweathermap.org/data/2.5/onecall?lat=%s&lon=%s&appid=%s&units=metric" % (lat, lon, api_key)
response = requests.get(url)
data = json.loads(response.text)

# %%
current = data["current"]["dt"]
print(current)
# Out:
# 1619447093

# %%
cities = ['Lisbon', 'Porto', 'Aveiro', 'Algarve', 'Beja', 'Coimbra', 'Madrid', 'Los Angeles', 'Tokyo', 'Seoul', 'Oslo']

# %%
df = pd.DataFrame()

# %%
# Python program to find current 
# weather details of any city
# using openweathermap api
  
# import required modules
import requests, json
  
# Enter your API key here
api_key = "4a6cee856dda9f4bb8bd40415da3ebde"
  
# base_url variable to store url
base_url = "http://api.openweathermap.org/data/2.5/weather?"
  
# Give city name
#city_name = input("Enter city name : ")

cities_dict = {'country': "",
               'city': "", 
               "curr_temp": "",
               "temp_feel": "",
               "curr_pressure": "",
               "curr_humidity": "",
               "clouds": "",
               "wth_descr": "",
               'long': "",
               "lat": "",
               'datetime': "",
               'rain': "",
               'wind_speed': "",
               "wind_degree": ""
              }

for city_name in cities:

    # complete_url variable to store
    # complete url address
    complete_url = base_url + "appid=" + api_key + "&q=" + city_name

    # get method of requests module
    # return response object
    response = requests.get(complete_url)

    # json method of response object 
    # convert json format data into
    # python format data
    x = response.json()
    #print(x)

    # Now x contains list of nested dictionaries
    # Check the value of "cod" key is equal to
    # "404", means city is found otherwise,
    # city is not found
    if x["cod"] != "404":

        #print(x)
        #print("")
        #print(y)

        # store the value of "main"
        # key in variable y
        y = x["main"]

        # store the value corresponding
        # to the "temp" key of y
        #current_temperature = y["temp"]
        cities_dict['curr_temp'] = y["temp"]

        # store the value corresponding
        # to the "pressure" key of y
        #current_pressure = y["pressure"]
        cities_dict['curr_pressure'] = y["pressure"]

        # store the value corresponding
        # to the "humidity" key of y
        #current_humidiy = y["humidity"]
        cities_dict['curr_humidity'] = y["humidity"]
        
        #clouds = x["clouds"]['all']
        cities_dict['clouds'] = x["clouds"]['all']
        
        #country = x['sys']['country']
        cities_dict['country'] = x['sys']['country']
        
        #temp_feel = y['feels_like']
        cities_dict['temp_feel'] = y['feels_like']
        
        lat = x['coord']['lat']
        cities_dict['lat'] = lat
        
        long = x['coord']['lon']
        cities_dict['long'] = long
        
        cities_dict['city'] = city_name
        
        datetime = x['dt']
        cities_dict['datetime'] = datetime
        
        visibility = x['visibility']
        cities_dict['visibility'] = visibility
        
        wind_speed = x['wind']['speed']
        cities_dict['wind_speed'] = wind_speed
        
        wind_degree = x['wind']['deg']
        cities_dict['wind_degree'] = wind_degree
        
        #rain = x['rain']
        #cities_dict['rain'] = rain[0]

        # store the value of "weather"
        # key in variable z
        z = x["weather"]

        # store the value corresponding 
        # to the "description" key at 
        # the 0th index of z
        weather_description = z[0]["description"]
        cities_dict['wth_descr'] = weather_description
        
        df = df.append(cities_dict, ignore_index=True)

    else:
        print(" City Not Found ")

# %%
df
# Out:
#            city  clouds country  curr_humidity  curr_pressure  curr_temp  \
# 0        Lisbon    20.0      PT           88.0         1006.0     290.92
# 1         Porto    20.0      PT           68.0         1007.0     293.05
# 2        Aveiro    20.0      PT           64.0         1006.0     294.21
# 3       Algarve    40.0      BR           72.0         1017.0     291.92
# 4          Beja     0.0      TN           56.0         1005.0     300.12
# 5       Coimbra    79.0      PT           61.0         1008.0     293.77
# 6        Madrid    40.0      ES           59.0         1006.0     290.83
# 7   Los Angeles     1.0      US           76.0         1012.0     284.85
# 8         Tokyo    20.0      JP           58.0         1022.0     285.83
# 9         Seoul     0.0      KR           76.0         1021.0     286.81
# 10         Oslo     9.0      NO           28.0         1018.0     283.76
#
#         datetime      lat      long rain  temp_feel  visibility  wind_degree  \
# 0   1.619447e+09  38.7167   -9.1333          291.05     10000.0        210.0
# 1   1.619447e+09  41.1496   -8.6110          292.87     10000.0        290.0
# 2   1.619448e+09  40.6443   -8.6455          294.04     10000.0        340.0
# 3   1.619448e+09 -30.0344  -51.0791          291.73     10000.0        290.0
# 4   1.619448e+09  36.7256    9.1817          300.92     10000.0        260.0
# 5   1.619448e+09  40.2056   -8.4195          293.48      9951.0        254.0
# 6   1.619447e+09  40.4165   -3.7026          290.19     10000.0        220.0
# 7   1.619447e+09  34.0522 -118.2437          284.06     10000.0        227.0
# 8   1.619447e+09  35.6895  139.6917          284.67     10000.0         80.0
# 9   1.619448e+09  37.5683  126.9778          286.22     10000.0        280.0
# 10  1.619447e+09  59.9127   10.7461          281.61     10000.0         62.0
#
#     wind_speed         wth_descr
# 0         4.12        few clouds
# 1         3.60        few clouds
# 2         5.14        few clouds
# 3         4.63  scattered clouds
# 4        10.80         clear sky
# 5         2.24     broken clouds
# 6         3.09  scattered clouds
# 7         1.70         clear sky
# 8         6.69        few clouds
# 9         1.03         clear sky
# 10        0.89         clear sky
